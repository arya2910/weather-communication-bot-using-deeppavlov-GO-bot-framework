# %% [markdown]
# <a href="https://colab.research.google.com/github/arya2910/weather-communication-bot-using-deeppavlov-GO-bot-framework/blob/main/weather_communication_bot_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ####install requirements
# !pip install deeppavlov
# !python -m deeppavlov install gobot_simple_dstc2
# !yes | pip uninstall tensorflow
# !pip install tensorflow-gpu==1.15.2
# Out:
# ...
# 2021-03-27 17:23:31.174 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'gobot_simple_dstc2' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/go_bot/gobot_simple_dstc2.json'
# ...
# 2021-03-27 17:23:38.678 WARNING in 'deeppavlov.utils.pip_wrapper.pip_wrapper'['pip_wrapper'] at line 34: found tensorflow-gpu installed, so upgrading it instead of tensorflow
# ...
# WARNING: Skipping tensorflow as it is not installed.
# ...

# %%
# !pip install deeppavlov

# %%
DP_MIN_DEMO_DIR = "dp_minimal_demo_dir"  # we will work in this folder
CONFIGS_BASE_URL = "http://files.deeppavlov.ai/workshop/gobot/"
import os

# %cd /content
os.makedirs(DP_MIN_DEMO_DIR, exist_ok=True)
# Out:
# /content

# %% [markdown]
# #### write configs

# %%
# %%writefile stories.md
#
# ## say goodbye
# * goodbye
#   - utter_goodbye
#
# ## weather long
# * greet
#   - utter_greet
# * weather
#   - utter_ask_location
# * city_info
#   - utter_getting_weather
#   - action_get_weather
# * thanks
#   - utter_welcome
#   - utter_goodbye
#
# ## weather short
# * greet
#   - utter_greet
# * weather_for_location
#   - utter_getting_weather
#   - action_get_weather
# * thanks
#   - utter_welcome
#   - utter_goodbye
#
# ## New Story
#
# * greet
#     - utter_greet
# * weather_for_location{"location":"London"}
#     - utter_getting_weather
#     - action_get_weather
# Out:
# Overwriting stories.md

# %%
# %%writefile nlu.md
#
# ## intent:greet
# - hey
# - hello
# - hi
# - good morning
# - good evening
# - hey there
#
# ## intent:goodbye
# - bye
# - goodbye
# - see you around
# - see you later
#
# ## intent:weather
# - what's the weather
# - what is the temperature today
# - what is the temperature
# - i want to know the temperature
# - i want to know the weather of today
# - tell me the weather forecast
# - hows the weather today
#
# ## intent:weather_for_location
# - what is the weather in [Noida](location)
# - what is the weather in [New Delhi](location)
# - weather of [Mumbai] (location)
# - Today's weather in [Bangalore](location)
# - [Kolkata](location) weather
# - Tell me weather of [Hyderabad](location)
# - Can you tell me weather of [London](location)
#
# ## intent:city_info
# - [New Delhi](location)
# - [India](location)
# - [Mumbai](location)
# - [Noida](location)
# - [Kolkata](location)
# - [Bangalore](location)
# - [London](location)
#
# ##intent: thanks
# - thanks
# - thank you
# - OK
# Out:
# Overwriting nlu.md

# %%
# %%writefile domain.yml
#
# session_config:
#   session_expiration_time: 60
#   carry_over_slots_to_new_session: true
#
# intents:
# - greet
# - goodbye
# - weather
# - weather_for_location
# - city_info
# - thanks
# entities:
# - location
# slots:
#   location:
#     type: text
# responses:
#   utter_greet:
#   - text: Hey!
#   utter_goodbye:
#   - text: Bye
#   - text: Good Bye
#   utter_ask_location:
#   - text: of where?
#   - text: In what city?
#   utter_getting_weather:
#   - text: Ok, getting weather of [location] ...
#   utter_welcome:
#   - text: Welcome
# actions:
# - action_get_weather
# Out:
# Overwriting domain.yml

# %%
# !pip install git+https://github.com/deepmipt/DeepPavlov.git@feature/gobot-md-yaml-config
# !python -m deeppavlov install gobot_simple_dstc2
# Out:
# ...
#   Cloning https://github.com/deepmipt/DeepPavlov.git (to revision feature/gobot-md-yaml-config) to /tmp/pip-req-build-dj0lyd6l
#   Running command git clone -q https://github.com/deepmipt/DeepPavlov.git /tmp/pip-req-build-dj0lyd6l
#   Running command git checkout -b feature/gobot-md-yaml-config --track origin/feature/gobot-md-yaml-config
#   Switched to a new branch 'feature/gobot-md-yaml-config'
#   Branch 'feature/gobot-md-yaml-config' set up to track remote branch 'feature/gobot-md-yaml-config' from 'origin'.
# ...
#   Created wheel for deeppavlov: filename=deeppavlov-0.11.0-cp37-none-any.whl size=868899 sha256=ebfc786435be45844dffd3710621380d21b59ef4dd33cffb8d23e586498708b6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bgihfyx9/wheels/d1/14/83/51a15d3d0cc9bf87e735c1daddf375ad226313aa14d8cd04d9
# Successfully built deeppavlov
# ...

# %%
# !cp stories.md stories-trn.md
# !cp stories.md stories-tst.md 
# !cp stories.md stories-val.md

# %% [markdown]
# #### train the system

# %% [markdown]
# ##### train the slotfiller

# %%
from deeppavlov.core.common.file import read_json
from deeppavlov import train_model

slotfill_config_fpath = f"{DP_MIN_DEMO_DIR}/slotfill_config.json"
# !wget -c {CONFIGS_BASE_URL}/slotfill_config.json -O {slotfill_config_fpath}

slotfill_config = read_json(slotfill_config_fpath)

slotfiller = train_model(slotfill_config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5fcab4ac44f4> in <module>()
#       2 from deeppavlov import train_model
#       3
# ----> 4 slotfill_config_fpath = f"{DP_MIN_DEMO_DIR}/slotfill_config.json"
#       5 get_ipython().system('wget -c {CONFIGS_BASE_URL}/slotfill_config.json -O {slotfill_config_fpath}')
#       6
#
# NameError: name 'DP_MIN_DEMO_DIR' is not defined

# %% [markdown]
# ##### train the intents classifier

# %%
from deeppavlov.core.common.file import read_json
from deeppavlov import train_model

intents_config_fpath = f"{DP_MIN_DEMO_DIR}/intents_config.json"
# !wget -c {CONFIGS_BASE_URL}/intents_config.json -O {intents_config_fpath}

intents_config = read_json(intents_config_fpath)

intents_c = train_model(intents_config, download=True)

# %% [markdown]
# ##### train the bot

# %%
from deeppavlov.core.common.file import read_json
from deeppavlov import train_model

gobot_config_fpath = f"{DP_MIN_DEMO_DIR}/gobot_config.json"
# !wget -c {CONFIGS_BASE_URL}/gobot_config.json -O {gobot_config_fpath}

gobot_config = read_json(gobot_config_fpath)

bot = train_model(gobot_config)
# Out:
# --2021-03-27 15:49:33--  http://files.deeppavlov.ai/workshop/gobot//gobot_config.json
# Resolving files.deeppavlov.ai (files.deeppavlov.ai)... 93.175.29.74
# Connecting to files.deeppavlov.ai (files.deeppavlov.ai)|93.175.29.74|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://files.deeppavlov.ai/workshop/gobot//gobot_config.json [following]
# --2021-03-27 15:49:33--  https://files.deeppavlov.ai/workshop/gobot//gobot_config.json
# Connecting to files.deeppavlov.ai (files.deeppavlov.ai)|93.175.29.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2383 (2.3K) [application/json]
# Saving to: ‘dp_minimal_demo_dir/gobot_config.json’
#
# dp_minimal_demo_dir 100%[===================>]   2.33K  --.-KB/s    in 0s
#
# 2021-03-27 15:49:34 (480 MB/s) - ‘dp_minimal_demo_dir/gobot_config.json’ saved [2383/2383]
# ---------------------------------------------------------------------------
# ...

# %%
bot.reset()
print(bot(["start"])[0][0].get_nlu_info()["intent"])
print(bot(["What is the weather today])[0][0].actions_tuple)
print(bot(["Weather in delhi?"])[0][0].get_nlu_info()["intent"])
# Out:
#   File "<ipython-input-12-b2dc86855404>", line 3
#     print(bot(["What is the weather today])[0][0].actions_tuple)
#                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
bot.pipe[-1][-1].nlu_manager.nlu(sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-355f1a7bb3c6> in <module>()
# ----> 1 bot.pipe[-1][-1].nlu_manager.nlu(sentence)
#
# NameError: name 'bot' is not defined

# %% [markdown]
# #### pack everything

# %%
# !tar -zcf {DP_MIN_DEMO_DIR}.tar.gz {DP_MIN_DEMO_DIR}
